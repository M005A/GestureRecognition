# I0604 17:50:03.176043 129448128780096 efficientnet_model.py:143] round_filter input=112 output=224
# I0604 17:50:03.576246 129448128780096 efficientnet_model.py:143] round_filter input=112 output=224
# I0604 17:50:03.576330 129448128780096 efficientnet_model.py:143] round_filter input=192 output=384
# I0604 17:50:04.099377 129448128780096 efficientnet_model.py:143] round_filter input=192 output=384
# I0604 17:50:04.099455 129448128780096 efficientnet_model.py:143] round_filter input=320 output=640
# I0604 17:50:04.265944 129448128780096 efficientnet_model.py:143] round_filter input=1280 output=2560
# I0604 17:50:04.284274 129448128780096 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 11.5s
# I0604 17:50:04.338384 129448128780096 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 11.5s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0604 17:50:04.351747 129448128780096 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0604 17:50:04.352654 129448128780096 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0604 17:50:04.352888 129448128780096 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0604 17:50:04.353511 129448128780096 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0604 17:50:04.354068 129448128780096 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0604 17:50:04.354254 129448128780096 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0604 17:50:04.354654 129448128780096 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 13.859s
#
# OK (skipped=1)

# %%
import object_detection

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# /bin/bash: /home/macho/miniconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# --2024-06-04 17:50:05--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 172.217.14.251, 142.250.217.123, 142.250.69.219, ...
# Connecting to download.tensorflow.org (download.tensorflow.org)|172.217.14.251|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.56M  30.7MB/s    in 0.6s
#
# 2024-06-04 17:50:05 (30.7 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]
#
# /bin/bash: /home/macho/miniconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/macho/miniconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # 2. Create Label Map

# %%
labels = [{'name':'ThumbsUp', 'id':1}, {'name':'ThumbsDown', 'id':2}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
# OPTIONAL IF RUNNING ON COLAB
ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
if os.path.exists(ARCHIVE_FILES):
  # !tar -zxvf {ARCHIVE_FILES}

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# /bin/bash: /home/macho/miniconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/train.record
# /bin/bash: /home/macho/miniconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Traceback (most recent call last):
#   File "/home/macho/Tensorflow Object Detection/TFODCourse/Tensorflow/scripts/generate_tfrecord.py", line 168, in <module>
#     tf.app.run()
#   File "/home/macho/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/platform/app.py", line 36, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/home/macho/miniconda3/envs/tf/lib/python3.9/site-packages/absl/app.py", line 308, in run
#     _run_main(main, args)
#   File "/home/macho/miniconda3/envs/tf/lib/python3.9/site-packages/absl/app.py", line 254, in _run_main
#     sys.exit(main(argv))
#   File "/home/macho/Tensorflow Object Detection/TFODCourse/Tensorflow/scripts/generate_tfrecord.py", line 158, in main
#     tf_example = create_tf_example(group, path)
#   File "/home/macho/Tensorflow Object Detection/TFODCourse/Tensorflow/scripts/generate_tfrecord.py", line 132, in create_tf_example
#     classes.append(class_text_to_int(row['class']))
#   File "/home/macho/Tensorflow Object Detection/TFODCourse/Tensorflow/scripts/generate_tfrecord.py", line 101, in class_text_to_int
#     return label_map_dict[row_label]
# KeyError: 'ThankYou'

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
# /bin/bash: /home/macho/miniconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %% [markdown]
# # 6. Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=100000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
# !{command}
# Out:
# /bin/bash: /home/macho/miniconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0604 17:50:14.464459 125891947935552 mirrored_strategy.py:419] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 100000
# I0604 17:50:14.483173 125891947935552 config_util.py:552] Maybe overwriting train_steps: 100000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0604 17:50:14.483264 125891947935552 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /home/macho/miniconda3/envs/tf/lib/python3.9/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0604 17:50:14.495992 125891947935552 deprecation.py:364] From /home/macho/miniconda3/envs/tf/lib/python3.9/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# I0604 17:50:14.503604 125891947935552 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# I0604 17:50:14.503701 125891947935552 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0604 17:50:14.503731 125891947935552 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0604 17:50:14.503754 125891947935552 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /home/macho/miniconda3/envs/tf/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0604 17:50:14.516242 125891947935552 deprecation.py:364] From /home/macho/miniconda3/envs/tf/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /home/macho/miniconda3/envs/tf/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0604 17:50:14.525722 125891947935552 deprecation.py:364] From /home/macho/miniconda3/envs/tf/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /home/macho/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0604 17:50:17.470210 125891947935552 deprecation.py:364] From /home/macho/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/macho/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0604 17:50:18.716767 125891947935552 deprecation.py:364] From /home/macho/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /home/macho/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0604 17:50:19.360742 125891947935552 deprecation.py:364] From /home/macho/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /home/macho/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0604 17:50:23.661737 125883062945472 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0604 17:50:26.958744 125883062945472 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0604 17:50:29.035721 125891947935552 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0604 17:50:29.037220 125891947935552 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0604 17:50:29.037848 125891947935552 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0604 17:50:29.038417 125891947935552 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0604 17:50:29.039940 125891947935552 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0604 17:50:29.040505 125891947935552 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0604 17:50:29.041054 125891947935552 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0604 17:50:29.041519 125891947935552 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0604 17:50:29.043400 125891947935552 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0604 17:50:29.043783 125891947935552 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /home/macho/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0604 17:50:29.518238 125883073431232 deprecation.py:569] From /home/macho/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0604 17:50:29.960485 125883073431232 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0604 17:50:32.178648 125883073431232 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0604 17:50:34.047537 125883073431232 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0604 17:50:36.199617 125883073431232 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# INFO:tensorflow:Step 100 per-step time 0.297s
# I0604 17:50:59.049368 125891947935552 model_lib_v2.py:705] Step 100 per-step time 0.297s
# INFO:tensorflow:{'Loss/classification_loss': 0.44961336,
#  'Loss/localization_loss': 0.40870664,
#  'Loss/regularization_loss': 0.15438147,
#  'Loss/total_loss': 1.0127015,
#  'learning_rate': 0.0319994}
# I0604 17:50:59.049601 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.44961336,
#  'Loss/localization_loss': 0.40870664,
#  'Loss/regularization_loss': 0.15438147,
#  'Loss/total_loss': 1.0127015,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.111s
# I0604 17:51:10.186115 125891947935552 model_lib_v2.py:705] Step 200 per-step time 0.111s
# INFO:tensorflow:{'Loss/classification_loss': 0.241531,
#  'Loss/localization_loss': 0.26535514,
#  'Loss/regularization_loss': 0.15478386,
#  'Loss/total_loss': 0.66166997,
#  'learning_rate': 0.0373328}
# I0604 17:51:10.186403 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.241531,
#  'Loss/localization_loss': 0.26535514,
#  'Loss/regularization_loss': 0.15478386,
#  'Loss/total_loss': 0.66166997,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.109s
# I0604 17:51:21.036556 125891947935552 model_lib_v2.py:705] Step 300 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.46266708,
#  'Loss/localization_loss': 0.2218509,
#  'Loss/regularization_loss': 0.15505287,
#  'Loss/total_loss': 0.8395709,
#  'learning_rate': 0.0426662}
# I0604 17:51:21.036851 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.46266708,
#  'Loss/localization_loss': 0.2218509,
#  'Loss/regularization_loss': 0.15505287,
#  'Loss/total_loss': 0.8395709,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.110s
# I0604 17:51:32.033359 125891947935552 model_lib_v2.py:705] Step 400 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.16563454,
#  'Loss/localization_loss': 0.20678757,
#  'Loss/regularization_loss': 0.15542357,
#  'Loss/total_loss': 0.5278457,
#  'learning_rate': 0.047999598}
# I0604 17:51:32.033538 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.16563454,
#  'Loss/localization_loss': 0.20678757,
#  'Loss/regularization_loss': 0.15542357,
#  'Loss/total_loss': 0.5278457,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.110s
# I0604 17:51:43.014508 125891947935552 model_lib_v2.py:705] Step 500 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.2954149,
#  'Loss/localization_loss': 0.24214971,
#  'Loss/regularization_loss': 0.15583713,
#  'Loss/total_loss': 0.69340175,
#  'learning_rate': 0.053333}
# I0604 17:51:43.014644 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.2954149,
#  'Loss/localization_loss': 0.24214971,
#  'Loss/regularization_loss': 0.15583713,
#  'Loss/total_loss': 0.69340175,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.109s
# I0604 17:51:53.916244 125891947935552 model_lib_v2.py:705] Step 600 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.1898819,
#  'Loss/localization_loss': 0.13500597,
#  'Loss/regularization_loss': 0.15602829,
#  'Loss/total_loss': 0.48091614,
#  'learning_rate': 0.0586664}
# I0604 17:51:53.916382 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.1898819,
#  'Loss/localization_loss': 0.13500597,
#  'Loss/regularization_loss': 0.15602829,
#  'Loss/total_loss': 0.48091614,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.108s
# I0604 17:52:04.768045 125891947935552 model_lib_v2.py:705] Step 700 per-step time 0.108s
# INFO:tensorflow:{'Loss/classification_loss': 0.2212743,
#  'Loss/localization_loss': 0.11046317,
#  'Loss/regularization_loss': 0.15609667,
#  'Loss/total_loss': 0.48783413,
#  'learning_rate': 0.0639998}
# I0604 17:52:04.768224 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.2212743,
#  'Loss/localization_loss': 0.11046317,
#  'Loss/regularization_loss': 0.15609667,
#  'Loss/total_loss': 0.48783413,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.109s
# I0604 17:52:15.637816 125891947935552 model_lib_v2.py:705] Step 800 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.1942465,
#  'Loss/localization_loss': 0.06621212,
#  'Loss/regularization_loss': 0.15608476,
#  'Loss/total_loss': 0.41654336,
#  'learning_rate': 0.069333196}
# I0604 17:52:15.637977 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.1942465,
#  'Loss/localization_loss': 0.06621212,
#  'Loss/regularization_loss': 0.15608476,
#  'Loss/total_loss': 0.41654336,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.110s
# I0604 17:52:26.647038 125891947935552 model_lib_v2.py:705] Step 900 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.19988932,
#  'Loss/localization_loss': 0.14215347,
#  'Loss/regularization_loss': 0.15627576,
#  'Loss/total_loss': 0.49831855,
#  'learning_rate': 0.074666604}
# I0604 17:52:26.647180 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.19988932,
#  'Loss/localization_loss': 0.14215347,
#  'Loss/regularization_loss': 0.15627576,
#  'Loss/total_loss': 0.49831855,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.110s
# I0604 17:52:37.604375 125891947935552 model_lib_v2.py:705] Step 1000 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.15412024,
#  'Loss/localization_loss': 0.114914194,
#  'Loss/regularization_loss': 0.15619092,
#  'Loss/total_loss': 0.42522538,
#  'learning_rate': 0.08}
# I0604 17:52:37.604548 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.15412024,
#  'Loss/localization_loss': 0.114914194,
#  'Loss/regularization_loss': 0.15619092,
#  'Loss/total_loss': 0.42522538,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.114s
# I0604 17:52:48.971957 125891947935552 model_lib_v2.py:705] Step 1100 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.19393918,
#  'Loss/localization_loss': 0.11467327,
#  'Loss/regularization_loss': 0.15621224,
#  'Loss/total_loss': 0.4648247,
#  'learning_rate': 0.07999918}
# I0604 17:52:48.972148 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.19393918,
#  'Loss/localization_loss': 0.11467327,
#  'Loss/regularization_loss': 0.15621224,
#  'Loss/total_loss': 0.4648247,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.109s
# I0604 17:52:59.858599 125891947935552 model_lib_v2.py:705] Step 1200 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.07946445,
#  'Loss/localization_loss': 0.04352716,
#  'Loss/regularization_loss': 0.15598902,
#  'Loss/total_loss': 0.2789806,
#  'learning_rate': 0.079996705}
# I0604 17:52:59.858789 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.07946445,
#  'Loss/localization_loss': 0.04352716,
#  'Loss/regularization_loss': 0.15598902,
#  'Loss/total_loss': 0.2789806,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.109s
# I0604 17:53:10.768124 125891947935552 model_lib_v2.py:705] Step 1300 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.14732487,
#  'Loss/localization_loss': 0.11159725,
#  'Loss/regularization_loss': 0.15625282,
#  'Loss/total_loss': 0.41517496,
#  'learning_rate': 0.0799926}
# I0604 17:53:10.768321 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.14732487,
#  'Loss/localization_loss': 0.11159725,
#  'Loss/regularization_loss': 0.15625282,
#  'Loss/total_loss': 0.41517496,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.111s
# I0604 17:53:21.858592 125891947935552 model_lib_v2.py:705] Step 1400 per-step time 0.111s
# INFO:tensorflow:{'Loss/classification_loss': 0.13775083,
#  'Loss/localization_loss': 0.118479095,
#  'Loss/regularization_loss': 0.15730314,
#  'Loss/total_loss': 0.4135331,
#  'learning_rate': 0.07998685}
# I0604 17:53:21.858821 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.13775083,
#  'Loss/localization_loss': 0.118479095,
#  'Loss/regularization_loss': 0.15730314,
#  'Loss/total_loss': 0.4135331,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.110s
# I0604 17:53:32.856472 125891947935552 model_lib_v2.py:705] Step 1500 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.11928158,
#  'Loss/localization_loss': 0.09057533,
#  'Loss/regularization_loss': 0.15694001,
#  'Loss/total_loss': 0.3667969,
#  'learning_rate': 0.07997945}
# I0604 17:53:32.856642 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.11928158,
#  'Loss/localization_loss': 0.09057533,
#  'Loss/regularization_loss': 0.15694001,
#  'Loss/total_loss': 0.3667969,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 0.110s
# I0604 17:53:43.854661 125891947935552 model_lib_v2.py:705] Step 1600 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.11426313,
#  'Loss/localization_loss': 0.05415212,
#  'Loss/regularization_loss': 0.15714075,
#  'Loss/total_loss': 0.32555598,
#  'learning_rate': 0.079970405}
# I0604 17:53:43.854842 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.11426313,
#  'Loss/localization_loss': 0.05415212,
#  'Loss/regularization_loss': 0.15714075,
#  'Loss/total_loss': 0.32555598,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.108s
# I0604 17:53:54.646712 125891947935552 model_lib_v2.py:705] Step 1700 per-step time 0.108s
# INFO:tensorflow:{'Loss/classification_loss': 0.0961663,
#  'Loss/localization_loss': 0.061013766,
#  'Loss/regularization_loss': 0.15686503,
#  'Loss/total_loss': 0.3140451,
#  'learning_rate': 0.07995972}
# I0604 17:53:54.646869 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.0961663,
#  'Loss/localization_loss': 0.061013766,
#  'Loss/regularization_loss': 0.15686503,
#  'Loss/total_loss': 0.3140451,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 0.110s
# I0604 17:54:05.615100 125891947935552 model_lib_v2.py:705] Step 1800 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.1307851,
#  'Loss/localization_loss': 0.045146246,
#  'Loss/regularization_loss': 0.15645662,
#  'Loss/total_loss': 0.33238795,
#  'learning_rate': 0.0799474}
# I0604 17:54:05.615301 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.1307851,
#  'Loss/localization_loss': 0.045146246,
#  'Loss/regularization_loss': 0.15645662,
#  'Loss/total_loss': 0.33238795,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 0.109s
# I0604 17:54:16.487385 125891947935552 model_lib_v2.py:705] Step 1900 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.09908889,
#  'Loss/localization_loss': 0.034797765,
#  'Loss/regularization_loss': 0.15581697,
#  'Loss/total_loss': 0.28970364,
#  'learning_rate': 0.07993342}
# I0604 17:54:16.487618 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.09908889,
#  'Loss/localization_loss': 0.034797765,
#  'Loss/regularization_loss': 0.15581697,
#  'Loss/total_loss': 0.28970364,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.109s
# I0604 17:54:27.399283 125891947935552 model_lib_v2.py:705] Step 2000 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.085168995,
#  'Loss/localization_loss': 0.05597794,
#  'Loss/regularization_loss': 0.15574862,
#  'Loss/total_loss': 0.29689556,
#  'learning_rate': 0.07991781}
# I0604 17:54:27.399454 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.085168995,
#  'Loss/localization_loss': 0.05597794,
#  'Loss/regularization_loss': 0.15574862,
#  'Loss/total_loss': 0.29689556,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 0.113s
# I0604 17:54:38.778249 125891947935552 model_lib_v2.py:705] Step 2100 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.13308015,
#  'Loss/localization_loss': 0.0922132,
#  'Loss/regularization_loss': 0.15535711,
#  'Loss/total_loss': 0.38065046,
#  'learning_rate': 0.07990056}
# I0604 17:54:38.778584 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.13308015,
#  'Loss/localization_loss': 0.0922132,
#  'Loss/regularization_loss': 0.15535711,
#  'Loss/total_loss': 0.38065046,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 0.110s
# I0604 17:54:49.707945 125891947935552 model_lib_v2.py:705] Step 2200 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.08464451,
#  'Loss/localization_loss': 0.031056438,
#  'Loss/regularization_loss': 0.15489905,
#  'Loss/total_loss': 0.2706,
#  'learning_rate': 0.07988167}
# I0604 17:54:49.708131 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.08464451,
#  'Loss/localization_loss': 0.031056438,
#  'Loss/regularization_loss': 0.15489905,
#  'Loss/total_loss': 0.2706,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 0.110s
# I0604 17:55:00.663506 125891947935552 model_lib_v2.py:705] Step 2300 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.063443616,
#  'Loss/localization_loss': 0.026663825,
#  'Loss/regularization_loss': 0.15426221,
#  'Loss/total_loss': 0.24436966,
#  'learning_rate': 0.07986114}
# I0604 17:55:00.663652 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.063443616,
#  'Loss/localization_loss': 0.026663825,
#  'Loss/regularization_loss': 0.15426221,
#  'Loss/total_loss': 0.24436966,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 0.112s
# I0604 17:55:11.833341 125891947935552 model_lib_v2.py:705] Step 2400 per-step time 0.112s
# INFO:tensorflow:{'Loss/classification_loss': 0.07021061,
#  'Loss/localization_loss': 0.032055523,
#  'Loss/regularization_loss': 0.15366292,
#  'Loss/total_loss': 0.25592905,
#  'learning_rate': 0.07983897}
# I0604 17:55:11.833615 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.07021061,
#  'Loss/localization_loss': 0.032055523,
#  'Loss/regularization_loss': 0.15366292,
#  'Loss/total_loss': 0.25592905,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 0.115s
# I0604 17:55:23.309604 125891947935552 model_lib_v2.py:705] Step 2500 per-step time 0.115s
# INFO:tensorflow:{'Loss/classification_loss': 0.091023505,
#  'Loss/localization_loss': 0.03690851,
#  'Loss/regularization_loss': 0.15295923,
#  'Loss/total_loss': 0.28089124,
#  'learning_rate': 0.079815164}
# I0604 17:55:23.309741 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.091023505,
#  'Loss/localization_loss': 0.03690851,
#  'Loss/regularization_loss': 0.15295923,
#  'Loss/total_loss': 0.28089124,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 0.110s
# I0604 17:55:34.347487 125891947935552 model_lib_v2.py:705] Step 2600 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.06024046,
#  'Loss/localization_loss': 0.027574077,
#  'Loss/regularization_loss': 0.15218796,
#  'Loss/total_loss': 0.2400025,
#  'learning_rate': 0.07978972}
# I0604 17:55:34.347627 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.06024046,
#  'Loss/localization_loss': 0.027574077,
#  'Loss/regularization_loss': 0.15218796,
#  'Loss/total_loss': 0.2400025,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 0.112s
# I0604 17:55:45.570967 125891947935552 model_lib_v2.py:705] Step 2700 per-step time 0.112s
# INFO:tensorflow:{'Loss/classification_loss': 0.07834572,
#  'Loss/localization_loss': 0.03237258,
#  'Loss/regularization_loss': 0.15157433,
#  'Loss/total_loss': 0.26229262,
#  'learning_rate': 0.07976264}
# I0604 17:55:45.571110 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.07834572,
#  'Loss/localization_loss': 0.03237258,
#  'Loss/regularization_loss': 0.15157433,
#  'Loss/total_loss': 0.26229262,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 0.109s
# I0604 17:55:56.518794 125891947935552 model_lib_v2.py:705] Step 2800 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.12500487,
#  'Loss/localization_loss': 0.046733957,
#  'Loss/regularization_loss': 0.15084767,
#  'Loss/total_loss': 0.3225865,
#  'learning_rate': 0.07973392}
# I0604 17:55:56.518993 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.12500487,
#  'Loss/localization_loss': 0.046733957,
#  'Loss/regularization_loss': 0.15084767,
#  'Loss/total_loss': 0.3225865,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 0.116s
# I0604 17:56:08.151882 125891947935552 model_lib_v2.py:705] Step 2900 per-step time 0.116s
# INFO:tensorflow:{'Loss/classification_loss': 0.07453109,
#  'Loss/localization_loss': 0.045188613,
#  'Loss/regularization_loss': 0.15014791,
#  'Loss/total_loss': 0.26986763,
#  'learning_rate': 0.07970358}
# I0604 17:56:08.152058 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.07453109,
#  'Loss/localization_loss': 0.045188613,
#  'Loss/regularization_loss': 0.15014791,
#  'Loss/total_loss': 0.26986763,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 0.111s
# I0604 17:56:19.225797 125891947935552 model_lib_v2.py:705] Step 3000 per-step time 0.111s
# INFO:tensorflow:{'Loss/classification_loss': 0.06766355,
#  'Loss/localization_loss': 0.053449936,
#  'Loss/regularization_loss': 0.14939748,
#  'Loss/total_loss': 0.27051097,
#  'learning_rate': 0.0796716}
# I0604 17:56:19.225975 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.06766355,
#  'Loss/localization_loss': 0.053449936,
#  'Loss/regularization_loss': 0.14939748,
#  'Loss/total_loss': 0.27051097,
#  'learning_rate': 0.0796716}
# INFO:tensorflow:Step 3100 per-step time 0.114s
# I0604 17:56:30.649251 125891947935552 model_lib_v2.py:705] Step 3100 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.10720916,
#  'Loss/localization_loss': 0.027241986,
#  'Loss/regularization_loss': 0.1487314,
#  'Loss/total_loss': 0.28318256,
#  'learning_rate': 0.07963799}
# I0604 17:56:30.649435 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.10720916,
#  'Loss/localization_loss': 0.027241986,
#  'Loss/regularization_loss': 0.1487314,
#  'Loss/total_loss': 0.28318256,
#  'learning_rate': 0.07963799}
# INFO:tensorflow:Step 3200 per-step time 0.110s
# I0604 17:56:41.662789 125891947935552 model_lib_v2.py:705] Step 3200 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.07676973,
#  'Loss/localization_loss': 0.03123018,
#  'Loss/regularization_loss': 0.14799994,
#  'Loss/total_loss': 0.25599986,
#  'learning_rate': 0.07960275}
# I0604 17:56:41.662942 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.07676973,
#  'Loss/localization_loss': 0.03123018,
#  'Loss/regularization_loss': 0.14799994,
#  'Loss/total_loss': 0.25599986,
#  'learning_rate': 0.07960275}
# INFO:tensorflow:Step 3300 per-step time 0.111s
# I0604 17:56:52.756636 125891947935552 model_lib_v2.py:705] Step 3300 per-step time 0.111s
# INFO:tensorflow:{'Loss/classification_loss': 0.088066,
#  'Loss/localization_loss': 0.026188174,
#  'Loss/regularization_loss': 0.14725626,
#  'Loss/total_loss': 0.26151043,
#  'learning_rate': 0.07956588}
# I0604 17:56:52.756771 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.088066,
#  'Loss/localization_loss': 0.026188174,
#  'Loss/regularization_loss': 0.14725626,
#  'Loss/total_loss': 0.26151043,
#  'learning_rate': 0.07956588}
# INFO:tensorflow:Step 3400 per-step time 0.109s
# I0604 17:57:03.664097 125891947935552 model_lib_v2.py:705] Step 3400 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.07302082,
#  'Loss/localization_loss': 0.03156997,
#  'Loss/regularization_loss': 0.14651482,
#  'Loss/total_loss': 0.2511056,
#  'learning_rate': 0.079527386}
# I0604 17:57:03.664277 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.07302082,
#  'Loss/localization_loss': 0.03156997,
#  'Loss/regularization_loss': 0.14651482,
#  'Loss/total_loss': 0.2511056,
#  'learning_rate': 0.079527386}
# INFO:tensorflow:Step 3500 per-step time 0.109s
# I0604 17:57:14.545366 125891947935552 model_lib_v2.py:705] Step 3500 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.047229007,
#  'Loss/localization_loss': 0.02732812,
#  'Loss/regularization_loss': 0.1457747,
#  'Loss/total_loss': 0.22033183,
#  'learning_rate': 0.07948727}
# I0604 17:57:14.545521 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.047229007,
#  'Loss/localization_loss': 0.02732812,
#  'Loss/regularization_loss': 0.1457747,
#  'Loss/total_loss': 0.22033183,
#  'learning_rate': 0.07948727}
# INFO:tensorflow:Step 3600 per-step time 0.108s
# I0604 17:57:25.386529 125891947935552 model_lib_v2.py:705] Step 3600 per-step time 0.108s
# INFO:tensorflow:{'Loss/classification_loss': 0.04495131,
#  'Loss/localization_loss': 0.052449815,
#  'Loss/regularization_loss': 0.14515212,
#  'Loss/total_loss': 0.24255325,
#  'learning_rate': 0.079445526}
# I0604 17:57:25.386720 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.04495131,
#  'Loss/localization_loss': 0.052449815,
#  'Loss/regularization_loss': 0.14515212,
#  'Loss/total_loss': 0.24255325,
#  'learning_rate': 0.079445526}
# INFO:tensorflow:Step 3700 per-step time 0.110s
# I0604 17:57:36.381586 125891947935552 model_lib_v2.py:705] Step 3700 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.036923405,
#  'Loss/localization_loss': 0.02119688,
#  'Loss/regularization_loss': 0.1444957,
#  'Loss/total_loss': 0.20261598,
#  'learning_rate': 0.07940216}
# I0604 17:57:36.381840 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.036923405,
#  'Loss/localization_loss': 0.02119688,
#  'Loss/regularization_loss': 0.1444957,
#  'Loss/total_loss': 0.20261598,
#  'learning_rate': 0.07940216}
# INFO:tensorflow:Step 3800 per-step time 0.108s
# I0604 17:57:47.179669 125891947935552 model_lib_v2.py:705] Step 3800 per-step time 0.108s
# INFO:tensorflow:{'Loss/classification_loss': 0.041047707,
#  'Loss/localization_loss': 0.015581826,
#  'Loss/regularization_loss': 0.1437536,
#  'Loss/total_loss': 0.20038313,
#  'learning_rate': 0.079357184}
# I0604 17:57:47.179847 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.041047707,
#  'Loss/localization_loss': 0.015581826,
#  'Loss/regularization_loss': 0.1437536,
#  'Loss/total_loss': 0.20038313,
#  'learning_rate': 0.079357184}
# INFO:tensorflow:Step 3900 per-step time 0.110s
# I0604 17:57:58.146684 125891947935552 model_lib_v2.py:705] Step 3900 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.053682428,
#  'Loss/localization_loss': 0.038242348,
#  'Loss/regularization_loss': 0.14306694,
#  'Loss/total_loss': 0.23499171,
#  'learning_rate': 0.07931058}
# I0604 17:57:58.146860 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.053682428,
#  'Loss/localization_loss': 0.038242348,
#  'Loss/regularization_loss': 0.14306694,
#  'Loss/total_loss': 0.23499171,
#  'learning_rate': 0.07931058}
# INFO:tensorflow:Step 4000 per-step time 0.110s
# I0604 17:58:09.112278 125891947935552 model_lib_v2.py:705] Step 4000 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.07268676,
#  'Loss/localization_loss': 0.022745911,
#  'Loss/regularization_loss': 0.14234005,
#  'Loss/total_loss': 0.23777272,
#  'learning_rate': 0.07926236}
# I0604 17:58:09.112515 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.07268676,
#  'Loss/localization_loss': 0.022745911,
#  'Loss/regularization_loss': 0.14234005,
#  'Loss/total_loss': 0.23777272,
#  'learning_rate': 0.07926236}
# INFO:tensorflow:Step 4100 per-step time 0.114s
# I0604 17:58:20.502628 125891947935552 model_lib_v2.py:705] Step 4100 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.0612688,
#  'Loss/localization_loss': 0.028387444,
#  'Loss/regularization_loss': 0.14166008,
#  'Loss/total_loss': 0.23131633,
#  'learning_rate': 0.07921253}
# I0604 17:58:20.502777 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.0612688,
#  'Loss/localization_loss': 0.028387444,
#  'Loss/regularization_loss': 0.14166008,
#  'Loss/total_loss': 0.23131633,
#  'learning_rate': 0.07921253}
# INFO:tensorflow:Step 4200 per-step time 0.111s
# I0604 17:58:31.588373 125891947935552 model_lib_v2.py:705] Step 4200 per-step time 0.111s
# INFO:tensorflow:{'Loss/classification_loss': 0.07855302,
#  'Loss/localization_loss': 0.03819429,
#  'Loss/regularization_loss': 0.14099678,
#  'Loss/total_loss': 0.2577441,
#  'learning_rate': 0.07916109}
# I0604 17:58:31.588542 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.07855302,
#  'Loss/localization_loss': 0.03819429,
#  'Loss/regularization_loss': 0.14099678,
#  'Loss/total_loss': 0.2577441,
#  'learning_rate': 0.07916109}
# INFO:tensorflow:Step 4300 per-step time 0.109s
# I0604 17:58:42.487499 125891947935552 model_lib_v2.py:705] Step 4300 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.066677466,
#  'Loss/localization_loss': 0.024560394,
#  'Loss/regularization_loss': 0.14034045,
#  'Loss/total_loss': 0.2315783,
#  'learning_rate': 0.07910804}
# I0604 17:58:42.487701 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.066677466,
#  'Loss/localization_loss': 0.024560394,
#  'Loss/regularization_loss': 0.14034045,
#  'Loss/total_loss': 0.2315783,
#  'learning_rate': 0.07910804}
# INFO:tensorflow:Step 4400 per-step time 0.110s
# I0604 17:58:53.487215 125891947935552 model_lib_v2.py:705] Step 4400 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.06948375,
#  'Loss/localization_loss': 0.038622115,
#  'Loss/regularization_loss': 0.13966197,
#  'Loss/total_loss': 0.24776784,
#  'learning_rate': 0.07905338}
# I0604 17:58:53.487376 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.06948375,
#  'Loss/localization_loss': 0.038622115,
#  'Loss/regularization_loss': 0.13966197,
#  'Loss/total_loss': 0.24776784,
#  'learning_rate': 0.07905338}
# INFO:tensorflow:Step 4500 per-step time 0.110s
# I0604 17:59:04.522499 125891947935552 model_lib_v2.py:705] Step 4500 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.050954264,
#  'Loss/localization_loss': 0.024067542,
#  'Loss/regularization_loss': 0.13904832,
#  'Loss/total_loss': 0.21407013,
#  'learning_rate': 0.07899711}
# I0604 17:59:04.522640 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.050954264,
#  'Loss/localization_loss': 0.024067542,
#  'Loss/regularization_loss': 0.13904832,
#  'Loss/total_loss': 0.21407013,
#  'learning_rate': 0.07899711}
# INFO:tensorflow:Step 4600 per-step time 0.110s
# I0604 17:59:15.512522 125891947935552 model_lib_v2.py:705] Step 4600 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.055419825,
#  'Loss/localization_loss': 0.021431703,
#  'Loss/regularization_loss': 0.13835202,
#  'Loss/total_loss': 0.21520355,
#  'learning_rate': 0.078939244}
# I0604 17:59:15.512715 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.055419825,
#  'Loss/localization_loss': 0.021431703,
#  'Loss/regularization_loss': 0.13835202,
#  'Loss/total_loss': 0.21520355,
#  'learning_rate': 0.078939244}
# INFO:tensorflow:Step 4700 per-step time 0.110s
# I0604 17:59:26.482821 125891947935552 model_lib_v2.py:705] Step 4700 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.045381073,
#  'Loss/localization_loss': 0.00895006,
#  'Loss/regularization_loss': 0.13777685,
#  'Loss/total_loss': 0.19210798,
#  'learning_rate': 0.07887978}
# I0604 17:59:26.482997 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.045381073,
#  'Loss/localization_loss': 0.00895006,
#  'Loss/regularization_loss': 0.13777685,
#  'Loss/total_loss': 0.19210798,
#  'learning_rate': 0.07887978}
# INFO:tensorflow:Step 4800 per-step time 0.110s
# I0604 17:59:37.453589 125891947935552 model_lib_v2.py:705] Step 4800 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.052414082,
#  'Loss/localization_loss': 0.020658184,
#  'Loss/regularization_loss': 0.1371059,
#  'Loss/total_loss': 0.21017817,
#  'learning_rate': 0.07881871}
# I0604 17:59:37.453868 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.052414082,
#  'Loss/localization_loss': 0.020658184,
#  'Loss/regularization_loss': 0.1371059,
#  'Loss/total_loss': 0.21017817,
#  'learning_rate': 0.07881871}
# INFO:tensorflow:Step 4900 per-step time 0.109s
# I0604 17:59:48.344861 125891947935552 model_lib_v2.py:705] Step 4900 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.099877745,
#  'Loss/localization_loss': 0.017073255,
#  'Loss/regularization_loss': 0.1365103,
#  'Loss/total_loss': 0.2534613,
#  'learning_rate': 0.07875605}
# I0604 17:59:48.345058 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.099877745,
#  'Loss/localization_loss': 0.017073255,
#  'Loss/regularization_loss': 0.1365103,
#  'Loss/total_loss': 0.2534613,
#  'learning_rate': 0.07875605}
# INFO:tensorflow:Step 5000 per-step time 0.110s
# I0604 17:59:59.334679 125891947935552 model_lib_v2.py:705] Step 5000 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.05591764,
#  'Loss/localization_loss': 0.023749756,
#  'Loss/regularization_loss': 0.13598761,
#  'Loss/total_loss': 0.215655,
#  'learning_rate': 0.078691795}
# I0604 17:59:59.334972 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.05591764,
#  'Loss/localization_loss': 0.023749756,
#  'Loss/regularization_loss': 0.13598761,
#  'Loss/total_loss': 0.215655,
#  'learning_rate': 0.078691795}
# INFO:tensorflow:Step 5100 per-step time 0.115s
# I0604 18:00:10.780080 125891947935552 model_lib_v2.py:705] Step 5100 per-step time 0.115s
# INFO:tensorflow:{'Loss/classification_loss': 0.044701528,
#  'Loss/localization_loss': 0.02435621,
#  'Loss/regularization_loss': 0.13533641,
#  'Loss/total_loss': 0.20439416,
#  'learning_rate': 0.07862595}
# I0604 18:00:10.780232 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.044701528,
#  'Loss/localization_loss': 0.02435621,
#  'Loss/regularization_loss': 0.13533641,
#  'Loss/total_loss': 0.20439416,
#  'learning_rate': 0.07862595}
# INFO:tensorflow:Step 5200 per-step time 0.110s
# I0604 18:00:21.804677 125891947935552 model_lib_v2.py:705] Step 5200 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.0554973,
#  'Loss/localization_loss': 0.012053248,
#  'Loss/regularization_loss': 0.13469414,
#  'Loss/total_loss': 0.2022447,
#  'learning_rate': 0.07855851}
# I0604 18:00:21.804872 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.0554973,
#  'Loss/localization_loss': 0.012053248,
#  'Loss/regularization_loss': 0.13469414,
#  'Loss/total_loss': 0.2022447,
#  'learning_rate': 0.07855851}
# INFO:tensorflow:Step 5300 per-step time 0.109s
# I0604 18:00:32.715577 125891947935552 model_lib_v2.py:705] Step 5300 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.04817148,
#  'Loss/localization_loss': 0.02564518,
#  'Loss/regularization_loss': 0.13402873,
#  'Loss/total_loss': 0.20784539,
#  'learning_rate': 0.07848949}
# I0604 18:00:32.715840 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.04817148,
#  'Loss/localization_loss': 0.02564518,
#  'Loss/regularization_loss': 0.13402873,
#  'Loss/total_loss': 0.20784539,
#  'learning_rate': 0.07848949}
# INFO:tensorflow:Step 5400 per-step time 0.110s
# I0604 18:00:43.665160 125891947935552 model_lib_v2.py:705] Step 5400 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.04262713,
#  'Loss/localization_loss': 0.016128005,
#  'Loss/regularization_loss': 0.13335863,
#  'Loss/total_loss': 0.19211376,
#  'learning_rate': 0.078418896}
# I0604 18:00:43.665304 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.04262713,
#  'Loss/localization_loss': 0.016128005,
#  'Loss/regularization_loss': 0.13335863,
#  'Loss/total_loss': 0.19211376,
#  'learning_rate': 0.078418896}
# INFO:tensorflow:Step 5500 per-step time 0.109s
# I0604 18:00:54.583120 125891947935552 model_lib_v2.py:705] Step 5500 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.039019372,
#  'Loss/localization_loss': 0.010031386,
#  'Loss/regularization_loss': 0.13277097,
#  'Loss/total_loss': 0.18182173,
#  'learning_rate': 0.078346714}
# I0604 18:00:54.583318 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.039019372,
#  'Loss/localization_loss': 0.010031386,
#  'Loss/regularization_loss': 0.13277097,
#  'Loss/total_loss': 0.18182173,
#  'learning_rate': 0.078346714}
# INFO:tensorflow:Step 5600 per-step time 0.110s
# I0604 18:01:05.536474 125891947935552 model_lib_v2.py:705] Step 5600 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.037062634,
#  'Loss/localization_loss': 0.017338205,
#  'Loss/regularization_loss': 0.13212655,
#  'Loss/total_loss': 0.1865274,
#  'learning_rate': 0.07827295}
# I0604 18:01:05.536655 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.037062634,
#  'Loss/localization_loss': 0.017338205,
#  'Loss/regularization_loss': 0.13212655,
#  'Loss/total_loss': 0.1865274,
#  'learning_rate': 0.07827295}
# INFO:tensorflow:Step 5700 per-step time 0.107s
# I0604 18:01:16.273240 125891947935552 model_lib_v2.py:705] Step 5700 per-step time 0.107s
# INFO:tensorflow:{'Loss/classification_loss': 0.04457116,
#  'Loss/localization_loss': 0.014717223,
#  'Loss/regularization_loss': 0.13147534,
#  'Loss/total_loss': 0.19076373,
#  'learning_rate': 0.07819763}
# I0604 18:01:16.273380 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.04457116,
#  'Loss/localization_loss': 0.014717223,
#  'Loss/regularization_loss': 0.13147534,
#  'Loss/total_loss': 0.19076373,
#  'learning_rate': 0.07819763}
# INFO:tensorflow:Step 5800 per-step time 0.110s
# I0604 18:01:27.287280 125891947935552 model_lib_v2.py:705] Step 5800 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.059314884,
#  'Loss/localization_loss': 0.020799173,
#  'Loss/regularization_loss': 0.13086504,
#  'Loss/total_loss': 0.2109791,
#  'learning_rate': 0.07812072}
# I0604 18:01:27.287439 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.059314884,
#  'Loss/localization_loss': 0.020799173,
#  'Loss/regularization_loss': 0.13086504,
#  'Loss/total_loss': 0.2109791,
#  'learning_rate': 0.07812072}
# INFO:tensorflow:Step 5900 per-step time 0.110s
# I0604 18:01:38.277241 125891947935552 model_lib_v2.py:705] Step 5900 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.052500863,
#  'Loss/localization_loss': 0.023026595,
#  'Loss/regularization_loss': 0.13029374,
#  'Loss/total_loss': 0.2058212,
#  'learning_rate': 0.078042254}
# I0604 18:01:38.277384 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.052500863,
#  'Loss/localization_loss': 0.023026595,
#  'Loss/regularization_loss': 0.13029374,
#  'Loss/total_loss': 0.2058212,
#  'learning_rate': 0.078042254}
# INFO:tensorflow:Step 6000 per-step time 0.112s
# I0604 18:01:49.438086 125891947935552 model_lib_v2.py:705] Step 6000 per-step time 0.112s
# INFO:tensorflow:{'Loss/classification_loss': 0.034824643,
#  'Loss/localization_loss': 0.017752632,
#  'Loss/regularization_loss': 0.12980662,
#  'Loss/total_loss': 0.1823839,
#  'learning_rate': 0.07796223}
# I0604 18:01:49.438264 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.034824643,
#  'Loss/localization_loss': 0.017752632,
#  'Loss/regularization_loss': 0.12980662,
#  'Loss/total_loss': 0.1823839,
#  'learning_rate': 0.07796223}
# INFO:tensorflow:Step 6100 per-step time 0.116s
# I0604 18:02:01.042190 125891947935552 model_lib_v2.py:705] Step 6100 per-step time 0.116s
# INFO:tensorflow:{'Loss/classification_loss': 0.06976947,
#  'Loss/localization_loss': 0.02719504,
#  'Loss/regularization_loss': 0.12918256,
#  'Loss/total_loss': 0.22614707,
#  'learning_rate': 0.077880636}
# I0604 18:02:01.042332 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.06976947,
#  'Loss/localization_loss': 0.02719504,
#  'Loss/regularization_loss': 0.12918256,
#  'Loss/total_loss': 0.22614707,
#  'learning_rate': 0.077880636}
# INFO:tensorflow:Step 6200 per-step time 0.109s
# I0604 18:02:11.904025 125891947935552 model_lib_v2.py:705] Step 6200 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.067575835,
#  'Loss/localization_loss': 0.013075118,
#  'Loss/regularization_loss': 0.12871428,
#  'Loss/total_loss': 0.20936523,
#  'learning_rate': 0.07779749}
# I0604 18:02:11.904163 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.067575835,
#  'Loss/localization_loss': 0.013075118,
#  'Loss/regularization_loss': 0.12871428,
#  'Loss/total_loss': 0.20936523,
#  'learning_rate': 0.07779749}
# INFO:tensorflow:Step 6300 per-step time 0.109s
# I0604 18:02:22.810475 125891947935552 model_lib_v2.py:705] Step 6300 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.062804244,
#  'Loss/localization_loss': 0.020623868,
#  'Loss/regularization_loss': 0.12810841,
#  'Loss/total_loss': 0.21153653,
#  'learning_rate': 0.07771279}
# I0604 18:02:22.810658 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.062804244,
#  'Loss/localization_loss': 0.020623868,
#  'Loss/regularization_loss': 0.12810841,
#  'Loss/total_loss': 0.21153653,
#  'learning_rate': 0.07771279}
# INFO:tensorflow:Step 6400 per-step time 0.110s
# I0604 18:02:33.761103 125891947935552 model_lib_v2.py:705] Step 6400 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.055250045,
#  'Loss/localization_loss': 0.021081151,
#  'Loss/regularization_loss': 0.12747803,
#  'Loss/total_loss': 0.20380923,
#  'learning_rate': 0.077626534}
# I0604 18:02:33.761337 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.055250045,
#  'Loss/localization_loss': 0.021081151,
#  'Loss/regularization_loss': 0.12747803,
#  'Loss/total_loss': 0.20380923,
#  'learning_rate': 0.077626534}
# ...
# INFO:tensorflow:Step 97300 per-step time 0.110s
# I0604 20:50:34.601669 125891947935552 model_lib_v2.py:705] Step 97300 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.02208906,
#  'Loss/localization_loss': 0.0014599,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.073491424,
#  'learning_rate': 0.0}
# I0604 20:50:34.601835 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.02208906,
#  'Loss/localization_loss': 0.0014599,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.073491424,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 97400 per-step time 0.109s
# I0604 20:50:45.499711 125891947935552 model_lib_v2.py:705] Step 97400 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.01030316,
#  'Loss/localization_loss': 0.0023187078,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.06256433,
#  'learning_rate': 0.0}
# I0604 20:50:45.499993 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.01030316,
#  'Loss/localization_loss': 0.0023187078,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.06256433,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 97500 per-step time 0.109s
# I0604 20:50:56.435095 125891947935552 model_lib_v2.py:705] Step 97500 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.011253856,
#  'Loss/localization_loss': 0.0011720645,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.06236838,
#  'learning_rate': 0.0}
# I0604 20:50:56.435240 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.011253856,
#  'Loss/localization_loss': 0.0011720645,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.06236838,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 97600 per-step time 0.109s
# I0604 20:51:07.412726 125891947935552 model_lib_v2.py:705] Step 97600 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.018189205,
#  'Loss/localization_loss': 0.0023552554,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.07048692,
#  'learning_rate': 0.0}
# I0604 20:51:07.413032 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.018189205,
#  'Loss/localization_loss': 0.0023552554,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.07048692,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 97700 per-step time 0.110s
# I0604 20:51:18.389016 125891947935552 model_lib_v2.py:705] Step 97700 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.022175487,
#  'Loss/localization_loss': 0.0023859537,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.0745039,
#  'learning_rate': 0.0}
# I0604 20:51:18.389160 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.022175487,
#  'Loss/localization_loss': 0.0023859537,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.0745039,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 97800 per-step time 0.111s
# I0604 20:51:29.466957 125891947935552 model_lib_v2.py:705] Step 97800 per-step time 0.111s
# INFO:tensorflow:{'Loss/classification_loss': 0.017119184,
#  'Loss/localization_loss': 0.0014569671,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.06851861,
#  'learning_rate': 0.0}
# I0604 20:51:29.467102 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.017119184,
#  'Loss/localization_loss': 0.0014569671,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.06851861,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 97900 per-step time 0.111s
# I0604 20:51:40.546508 125891947935552 model_lib_v2.py:705] Step 97900 per-step time 0.111s
# INFO:tensorflow:{'Loss/classification_loss': 0.012567026,
#  'Loss/localization_loss': 0.0017196554,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.06422914,
#  'learning_rate': 0.0}
# I0604 20:51:40.546700 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.012567026,
#  'Loss/localization_loss': 0.0017196554,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.06422914,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 98000 per-step time 0.111s
# I0604 20:51:51.614275 125891947935552 model_lib_v2.py:705] Step 98000 per-step time 0.111s
# INFO:tensorflow:{'Loss/classification_loss': 0.015963709,
#  'Loss/localization_loss': 0.0024187793,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.068324946,
#  'learning_rate': 0.0}
# I0604 20:51:51.614466 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.015963709,
#  'Loss/localization_loss': 0.0024187793,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.068324946,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 98100 per-step time 0.114s
# I0604 20:52:03.010185 125891947935552 model_lib_v2.py:705] Step 98100 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.013960508,
#  'Loss/localization_loss': 0.0022478448,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.066150814,
#  'learning_rate': 0.0}
# I0604 20:52:03.010341 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.013960508,
#  'Loss/localization_loss': 0.0022478448,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.066150814,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 98200 per-step time 0.109s
# I0604 20:52:13.930324 125891947935552 model_lib_v2.py:705] Step 98200 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.027506977,
#  'Loss/localization_loss': 0.001093969,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.07854341,
#  'learning_rate': 0.0}
# I0604 20:52:13.930491 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.027506977,
#  'Loss/localization_loss': 0.001093969,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.07854341,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 98300 per-step time 0.110s
# I0604 20:52:24.881630 125891947935552 model_lib_v2.py:705] Step 98300 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.018989036,
#  'Loss/localization_loss': 0.0021483116,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.071079805,
#  'learning_rate': 0.0}
# I0604 20:52:24.881793 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.018989036,
#  'Loss/localization_loss': 0.0021483116,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.071079805,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 98400 per-step time 0.110s
# I0604 20:52:35.838463 125891947935552 model_lib_v2.py:705] Step 98400 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.017453633,
#  'Loss/localization_loss': 0.0019204823,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.06931657,
#  'learning_rate': 0.0}
# I0604 20:52:35.838631 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.017453633,
#  'Loss/localization_loss': 0.0019204823,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.06931657,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 98500 per-step time 0.109s
# I0604 20:52:46.742618 125891947935552 model_lib_v2.py:705] Step 98500 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.033212163,
#  'Loss/localization_loss': 0.013842935,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.09699756,
#  'learning_rate': 0.0}
# I0604 20:52:46.742774 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.033212163,
#  'Loss/localization_loss': 0.013842935,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.09699756,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 98600 per-step time 0.110s
# I0604 20:52:57.716541 125891947935552 model_lib_v2.py:705] Step 98600 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.014946591,
#  'Loss/localization_loss': 0.0017854642,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.066674516,
#  'learning_rate': 0.0}
# I0604 20:52:57.716713 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.014946591,
#  'Loss/localization_loss': 0.0017854642,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.066674516,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 98700 per-step time 0.110s
# I0604 20:53:08.702601 125891947935552 model_lib_v2.py:705] Step 98700 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.005459345,
#  'Loss/localization_loss': 0.0015750838,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.05697689,
#  'learning_rate': 0.0}
# I0604 20:53:08.702873 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.005459345,
#  'Loss/localization_loss': 0.0015750838,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.05697689,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 98800 per-step time 0.111s
# I0604 20:53:19.809419 125891947935552 model_lib_v2.py:705] Step 98800 per-step time 0.111s
# INFO:tensorflow:{'Loss/classification_loss': 0.012965771,
#  'Loss/localization_loss': 0.002107319,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.065015554,
#  'learning_rate': 0.0}
# I0604 20:53:19.809621 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.012965771,
#  'Loss/localization_loss': 0.002107319,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.065015554,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 98900 per-step time 0.111s
# I0604 20:53:30.911803 125891947935552 model_lib_v2.py:705] Step 98900 per-step time 0.111s
# INFO:tensorflow:{'Loss/classification_loss': 0.0238813,
#  'Loss/localization_loss': 0.0038885677,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.07771233,
#  'learning_rate': 0.0}
# I0604 20:53:30.911968 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.0238813,
#  'Loss/localization_loss': 0.0038885677,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.07771233,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 99000 per-step time 0.109s
# I0604 20:53:41.821552 125891947935552 model_lib_v2.py:705] Step 99000 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.00989997,
#  'Loss/localization_loss': 0.0018222225,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.061664652,
#  'learning_rate': 0.0}
# I0604 20:53:41.821710 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.00989997,
#  'Loss/localization_loss': 0.0018222225,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.061664652,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 99100 per-step time 0.115s
# I0604 20:53:53.312791 125891947935552 model_lib_v2.py:705] Step 99100 per-step time 0.115s
# INFO:tensorflow:{'Loss/classification_loss': 0.025896935,
#  'Loss/localization_loss': 0.0014758173,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.07731521,
#  'learning_rate': 0.0}
# I0604 20:53:53.312981 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.025896935,
#  'Loss/localization_loss': 0.0014758173,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.07731521,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 99200 per-step time 0.109s
# I0604 20:54:04.251716 125891947935552 model_lib_v2.py:705] Step 99200 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.013884277,
#  'Loss/localization_loss': 0.00135171,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.06517845,
#  'learning_rate': 0.0}
# I0604 20:54:04.251931 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.013884277,
#  'Loss/localization_loss': 0.00135171,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.06517845,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 99300 per-step time 0.110s
# I0604 20:54:15.223763 125891947935552 model_lib_v2.py:705] Step 99300 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.02003542,
#  'Loss/localization_loss': 0.002016823,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.07199471,
#  'learning_rate': 0.0}
# I0604 20:54:15.223986 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.02003542,
#  'Loss/localization_loss': 0.002016823,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.07199471,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 99400 per-step time 0.110s
# I0604 20:54:26.211115 125891947935552 model_lib_v2.py:705] Step 99400 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.010706442,
#  'Loss/localization_loss': 0.001971743,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.06262065,
#  'learning_rate': 0.0}
# I0604 20:54:26.211358 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.010706442,
#  'Loss/localization_loss': 0.001971743,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.06262065,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 99500 per-step time 0.110s
# I0604 20:54:37.209831 125891947935552 model_lib_v2.py:705] Step 99500 per-step time 0.110s
# INFO:tensorflow:{'Loss/classification_loss': 0.018018624,
#  'Loss/localization_loss': 0.001814791,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.06977588,
#  'learning_rate': 0.0}
# I0604 20:54:37.210114 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.018018624,
#  'Loss/localization_loss': 0.001814791,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.06977588,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 99600 per-step time 0.109s
# I0604 20:54:48.094022 125891947935552 model_lib_v2.py:705] Step 99600 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.015331201,
#  'Loss/localization_loss': 0.001234422,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.066508085,
#  'learning_rate': 0.0}
# I0604 20:54:48.094189 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.015331201,
#  'Loss/localization_loss': 0.001234422,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.066508085,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 99700 per-step time 0.112s
# I0604 20:54:59.317523 125891947935552 model_lib_v2.py:705] Step 99700 per-step time 0.112s
# INFO:tensorflow:{'Loss/classification_loss': 0.024869213,
#  'Loss/localization_loss': 0.0016615833,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.07647326,
#  'learning_rate': 0.0}
# I0604 20:54:59.317723 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.024869213,
#  'Loss/localization_loss': 0.0016615833,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.07647326,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 99800 per-step time 0.111s
# I0604 20:55:10.395213 125891947935552 model_lib_v2.py:705] Step 99800 per-step time 0.111s
# INFO:tensorflow:{'Loss/classification_loss': 0.011968331,
#  'Loss/localization_loss': 0.0020881805,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.063998975,
#  'learning_rate': 0.0}
# I0604 20:55:10.395405 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.011968331,
#  'Loss/localization_loss': 0.0020881805,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.063998975,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 99900 per-step time 0.109s
# I0604 20:55:21.251960 125891947935552 model_lib_v2.py:705] Step 99900 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.018062875,
#  'Loss/localization_loss': 0.0022818113,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.070287146,
#  'learning_rate': 0.0}
# I0604 20:55:21.252231 125891947935552 model_lib_v2.py:708] {'Loss/classification_loss': 0.018062875,
#  'Loss/localization_loss': 0.0022818113,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.070287146,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 100000 per-step time 0.109s
# I0604 20:55:32.180373 125891947935552 model_lib_v2.py:705] Step 100000 per-step time 0.109s
# INFO:tensorflow:{'Loss/classification_loss': 0.009334322,
#  'Loss/localization_loss': 0.001381075,
#  'Loss/regularization_loss': 0.04994246,
#  'Loss/total_loss': 0.